# %%
# write the output to a csv file
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

my_url = "https://www.dell.com"

# Opening the connection and grabbing the page
uClient = uReq(my_url)
page_html = uClient.read()
uClient.close()

#html parsing
page_soup = soup(page_html, "html.parser")
page_soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en-US">
# <head>
# <title>Computers, Monitors &amp; Technology Solutions | Dell USA</title>
# <meta content="us" name="COUNTRY"/>
# <meta content="en" name="LANGUAGE"/>
# <meta content="us" name="REGION"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="ver:1.0.1.5739,gen @ 11/11/20 03:45:22" name="generator"/>
# <meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/>
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <meta content="Computers, Monitors &amp; Technology Solutions | Dell USA" name="TITLE"/>
# <meta content="Shop the latest Dell computers &amp;amp; technology solutions. Laptops, desktops, gaming pcs, monitors, workstations &amp;amp; servers. FREE &amp;amp; FAST DELIVERY" name="description"/>
# <meta content="Dell.com USA, computers, laptops, desktops, gaming pcs, workstations, monitors, servers, services" name="keywords"/>
# <meta content="https://www.dell.com" name="CHANNEL"/>
# <meta content="https://www.dell.com/en-us" property="og:url"/>
# <meta content="Computers, Monitors &amp; Technology Solutions | Dell USA" property="og:title"/>
# <meta content="Shop the latest Dell computers &amp;amp; technology solutions. Laptops, desktops, gaming pcs, monitors, workstations &amp;amp; servers. FREE &amp;amp; FAST DELIVERY" property="og:description"/>
# <meta content="Homepage" property="og:type"/>
# <meta content="https://i.dell.com/sites/imagecontent/app-merchandizing/responsive/Shop/Browse/PublishingImages/dell-social-logo.jpg" property="og:image"/>
# <meta content="Dell" property="og:site_name"/>
# <meta content="https://www.dell.com/en-us" name="twitter:url"/>
# <meta content="Computers, Monitors &amp; Technology Solutions | Dell USA" name="twitter:title"/>
# <meta content="Shop the latest Dell computers &amp;amp; technology solutions. Laptops, desktops, gaming pcs, monitors, workstations &amp;amp; servers. FREE &amp;amp; FAST DELIVERY" name="twitter:description"/>
# <meta content="Homepage" name="twitter:card"/>
# <meta content="https://i.dell.com/sites/imagecontent/app-merchandizing/responsive/Shop/Browse/PublishingImages/dell-social-logo.jpg" name="twitter:image"/>
# <meta content="@Dell" name="twitter:site"/>
# <meta content="0;172.16.0.193:61064" name="SMch"/>
# <meta content="dell" name="dc"/>
# <meta content="ver:1.0.1.5739,environment:Production,gen @ 11/11/20 03:45:22,DC:PC1" name="info"/>
# <meta content="false" name="bodyhiding"/>
# <meta content="dell.com responsive homepage" name="PAGENAME"/>
# <meta content="11/10/20 02:25:19" name="LASTMODIFIEDDATE"/>
# <meta content="index,follow" name="robots"/>
# <script type="application/ld+json">
#         {
#         "@context": "https://schema.org",
#         "@type": "WebPage",
#         "name": "Computers, Monitors &amp; Technology Solutions | Dell USA",
#         "description": "Shop the latest Dell computers &amp;amp; technology solutions. Laptops, desktops, gaming pcs, monitors, workstations &amp;amp; servers. FREE &amp;amp; FAST DELIVERY",
#         "url": "https://www.dell.com/en-us"
#         }
#     </script>
# <!-- preconnect (DNS, TCP, TLS) - limited modern browser support (Firefox 54+, Chrome 49+, Opera 47+, Android Browser 46+, Chrome for Android 59+) -->
# <link href="//i.dell.com" rel="preconnect"/>
# <link href="//nsm.dell.com" rel="preconnect"/>
# <link href="//sm.dell.com" rel="preconnect"/>
# <link href="//dpm.demdex.net" rel="preconnect"/>
# <link href="//nexus.ensighten.com" rel="preconnect"/>
# <link href="//nexus.dell.com" rel="preconnect"/>
# <link href="//cdnssl.clicktale.net" rel="preconnect"/>
# <link href="//c.evidon.com" rel="preconnect"/>
# <!-- dns-prefetch (DNS Lookup only) - wider browser support (IE11, Edge, Firefox 54+, Chrome 49+, Safari 10.1+, Opera 47+, Chrome For Android 59+) -->
# <link href="//i.dell.com" rel="dns-prefetch"/>
# <link href="//nsm.dell.com" rel="dns-prefetch"/>
# <link href="//sm.dell.com" rel="dns-prefetch"/>
# <link href="//recommendations.production.p13n.dell.com" rel="dns-prefetch"/>
# <link href="//dellinc.tt.omtrdc.net" rel="dns-prefetch"/>
# <link href="//dpm.demdex.net" rel="dns-prefetch"/>
# <link href="//nexus.dell.com" rel="dns-prefetch"/>
# <link href="//nexus.ensighten.com" rel="dns-prefetch"/>
# <link href="//cdnssl.clicktale.net" rel="dns-prefetch"/>
# <link href="//c.evidon.com" rel="dns-prefetch"/>
# <link as="font" crossorigin="anonymous" href="//fcs.dellcdn.com/fonts/roboto-normal.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="//afcs.dellcdn.com/csb/homepage/fonts/roboto-v20-latin-300.woff2" rel="preload" type="font/woff2"/>
# <script>
#     Dell = window.Dell || {};
#     Dell.Metrics = Dell.Metrics || {};
#     Dell.Metrics.sc = Dell.Metrics.sc || {};
#     window.Dell.Metrics.sc = {"country":"us","language":"en","segment":"gen","customerset":"uscorp1","pagename":"dell.com responsive homepage","applicationname":"homepage","s_account":"dellglobalonline","dc":"dell","cms":"stp","prod":"true","module":"csb_homepage","dellexperiment":"","bodyhiding":"false","hppersona":""};
# </script>
# <link href="https://www.dell.com/en-us" rel="canonical"/>
# <link href="//afcs.dellcdn.com/shop/styles/global-bundle.min.12417ea89e88a9153c68411debbf900d.css" rel="stylesheet"/>
# <link href="//afcs.dellcdn.com/csb/homepage/bundles/1.0.1.5739/css/site.min.css" rel="stylesheet"/>
# <script src="//afcs.dellcdn.com/tnt/adobebundle/shop/bundle_toggle.min.js"></script>
# <script>var dellScriptLoader = (function () {
# 	"use strict";
#
# 	var scriptsArray = [];
# 	var urlRegex = /^(https:\/\/www\.|https:\/\/|\/\/|\/)?[a-z0-9]+([\-\.]{1}[a-z0-9]+)*\.[a-z]{2,5}(:[0-9]{1,5})?(\/.*)?$/; //exit if not a url or an array
#
# 	function scriptsArrayCopy() {
# 		return JSON.parse(JSON.stringify(scriptsArray));
# 	}
#
# 	function load(scripts) {
# 		//check for valid url
# 		function isValidUrl(url) {
# 			return typeof url === "string" && urlRegex.test(url);
# 		}
#
# 		//check for array
# 		function isValidArray(scripts) {
# 			return Array.isArray(scripts);
# 		}
#
# 		if (!(isValidUrl(scripts) || isValidArray(scripts))) {
# 			return;
# 		}
#
# 		//single url being passed
# 		if (isValidUrl(scripts)) {
#             scriptsArray.push(scripts);
#             return;
# 		}
#
# 		//handling of array
# 		if (isValidArray(scripts)) {
# 			for (var i = 0; i < scripts.length; ++i) {
# 				var _script = scripts[i];
#
# 				//if array of strings
# 				if (typeof _script === "string" && isValidUrl(_script)) {
#                     scriptsArray.push({ url: _script });
#                     return;
# 				}
#
# 				//if array of objects with url and order
#                 if (_script.hasOwnProperty("url") && _script.hasOwnProperty("order") && !isNaN(Number(_script.order))) {
# 					_script.order = Number(_script.order);
# 					scriptsArray.push(_script);
#                     return;
# 				}
#
# 				//if array of objects with only url
#                 if (_script.hasOwnProperty("url") && isValidUrl(_script.url)) {
#                     scriptsArray.push(_script);
#                     return;
# 				}
# 			}
# 		}
# 	}
#
# 	return Object.freeze({
# 		load: load,
# 		scriptsArrayCopy: scriptsArrayCopy
# 	});
# })();
# </script>
# </head>
# <body namespace="homepage">
# <main>
# <h1 class="hmp-visually-hidden">Computers, Monitors &amp; Technology Solutions | Dell USA</h1>
# <style>[component=masthead] .cart-menu-behavior .mh-cart-trigger-wrap,[component=masthead].mh-show-cart-dropdown .mh-cart-trigger-wrap{background:#fff}[component=masthead] .cart-menu-behavior .mh-cart-trigger-wrap>.mh-cart-trigger,[component=masthead].mh-show-cart-dropdown .mh-cart-trigger-wrap>.mh-cart-trigger{color:#444}[component=masthead] .cart-menu-behavior .mh-cart-trigger-wrap .cf-masthead-icon,[component=masthead].mh-show-cart-dropdown .mh-cart-trigger-wrap .cf-masthead-icon{fill:#444}[component=masthead] .cart-menu-behavior .mh-ct-dropdown-wrap{left:auto;right:0;position:relative;display:block}@media only screen and (min-width:320px) and (max-width:766px){[component=masthead] .cart-menu-behavior .mh-ct-dropdown-wrap{left:0;position:absolute}}[component=masthead].mh-show-cart-dropdown .mh-ct-dropdown-wrap{left:auto;right:0;position:relative;display:block}@media only screen and (min-width:320px) and (max-width:766px){[component=masthead].mh-show-cart-dropdown .mh-ct-dropdown-wrap{left:0;position:absolute}}[component=masthead] .mh-ct-dropdown-wrap{display:none;position:relative}[component=masthead] a.mh-cart-trigger{display:-webkit-box;display:-ms-flexbox;display:flex;height:66px;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;padding:10px;-webkit-box-orient:vertical;-webkit-box-direction:normal;-ms-flex-direction:column;flex-direction:column;font-size:12px;line-height:1.15}@media only screen and (min-width:767px){[component=masthead] a.mh-cart-trigger{-webkit-box-orient:horizontal;-webkit-box-direction:normal;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:center;-ms-flex-pack:center;justify-content:center;padding-top:0;padding-bottom:0;font-size:14px}}@media only screen and (min-width:320px) and (max-width:766px){[component=masthead] a.mh-cart-trigger{padding:10px 5px}[component=masthead] a.mh-cart-trigger>span:nth-child(2){display:block;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;max-width:42px;padding-top:9px}}[component=masthead] .mh-ct-icon-wrap{width:25px;margin-right:5px;position:relative}[component=masthead] .mh-ct-icon-wrap svg{width:26px;height:20px}[component=masthead] [mh-show-bubble=true]:before{content:attr(mh-bubble-count);border-radius:50%;background:#006bbd;width:17px;height:17px;position:absolute;right:-7px;top:-9px;color:#fff;font-weight:700;font-size:10px;text-align:center;line-height:17px}[component=masthead] .mh-ct-home-dropdown{font-size:14px;position:absolute;right:0;top:100%;text-align:left;min-height:80px;width:320px;background-color:#fff;border:1px solid #cce7f3;border-top:0;border-bottom:4px solid #007db8;padding:0;z-index:999}@media only screen and (min-width:320px) and (max-width:766px){[component=masthead] .mh-ct-home-dropdown{width:100%}}[component=masthead] .mh-ct-dropdown{font-size:14px;position:absolute;right:0;top:100%;text-align:left;min-height:100px;width:320px;background-color:#fff;border:1px solid #cce7f3;border-top:0;border-bottom:4px solid #007db8;padding:15px 15px 0;z-index:999}@media only screen and (min-width:320px) and (max-width:766px){[component=masthead] .mh-ct-dropdown{width:100%}}[component=masthead] .mh-ct-dropdown .mh-ct-dd-content>h2{font-size:16px;margin:0 0 7px;font-weight:400}[component=masthead] .mh-ct-dropdown .mh-ct-dd-content>h2 .mh-ct-st-item-count{color:#aaa}[component=masthead] .mh-ct-dropdown .mh-ct-dd-content>button{width:100%}[component=masthead] .mh-ct-dd-content{display:none}[component=masthead] .mh-ct-dd-content.mh-ct-dd-show{display:block}[component=masthead] .mh-saved-carts-count{display:inline-block;color:#aaa;margin:0 0 0 2px}[component=masthead] .mh-saved-cart-total{-webkit-box-flex:0;-ms-flex:none;flex:none}[component=masthead] .mh-ct-dd-cartInfo{display:block;padding:10px 15px 0}[component=masthead] .mh-ct-hp-subtotal-wrap{-webkit-box-pack:justify;-ms-flex-pack:justify;justify-content:space-between;display:-webkit-box;display:-ms-flexbox;display:flex}[component=masthead] .mh-ct-hp-sub ...
# <header cart-service="//www.dell.com/csbapi/en-us/cart" class="vertical-fill mh-si-state-is-cold" component="masthead" consumer-customerset="19" country="us" country-svc="//www.dell.com/csbapi/masthead/countrylist/us/en" cust-set="uscorp1" cust-srv="//www.dell.com/csbapi/en-us/personalization" env-domain="https://www.dell.com" grey-out-disabled="false" id="dell-masthead" is-homepage="true" is-mist-theme="true" is-p1-nod="false" is-p2-nod="false" lang="en" ooc-api-url="//www.dell.com/csbapi/masthead/oocmessage/us/en" ooc-cookies-duration-days="30" ooc-message-enabled="true" persist-srch="false" region="us" search-redirect="//www.dell.com/en-us/search/" segment="gen" show-cart-bubble-count="true" sign-in-flyout-enabled="false" srch-svc="//pilot.search.dell.com/">
# <div class="mh-top-wrap mh-container">
# <div class="mh-tw-left-col">
# <div class="mh-tw-home-wrap mh-hover-behavior">
# <a aria-label="//www.dell.com/en-us?~ck=mn" class="cf-dell-home" href="//www.dell.com/en-us?~ck=mn">
# <svg height="32" version="1.1" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
# <path d="M16 0.3c-8.6 0-15.7 7.1-15.7 15.7s7 15.7 15.7 15.7 15.7-7 15.7-15.7-7.1-15.7-15.7-15.7zM16 30.1c-7.8 0-14.1-6.3-14.1-14.1s6.3-14.1 14.1-14.1 14.1 6.3 14.1 14.1-6.3 14.1-14.1 14.1zM28.2 18.1v1.4h-4.4v-6.9h1.6v5.5h2.8zM7.7 19.4c1.6 0 3-1.1 3.3-2.6l3.9 3 3.9-3v2.6h4.4v-1.4h-2.9v-5.5h-1.6v2.6l-3.7 3-0.8-0.7 1.8-1.4 1.9-1.5-1.1-0.9-3.7 2.9-0.8-0.7 3.7-2.8-1.1-0.9-3.9 3c-0.4-1.5-1.7-2.6-3.3-2.6h-2.8v6.9c0 0 2.8 0 2.8 0zM6.4 18.1v-4.2h1.2c1 0 1.9 0.9 1.9 2.1 0 1.1-0.8 2.1-1.9 2.1 0 0-1.2 0-1.2 0z"></path>
# </svg>
# </a>
# </div>
# <div class="mh-tw-search-wrap">
# <div class="mh-search-wrap" role="search">
# <input aria-label="Search" autocomplete="off" class="mh-search-input" placeholder="What can we help you find?" type="text"/>
# <button class="mh-btn mh-btn-primary mh-search-btn">
# <span class="mh-search-button-label">Search</span>
# <span class="mh-mobile-search-icon">
# <svg height="32" version="1.1" viewbox="0 0 43 32" width="43" xmlns="http://www.w3.org/2000/svg">
# <path class="mh-masthead-icon" d="M36.523 27.225l-9.613-9.493c1.133-1.782 1.789-3.892 1.789-6.154 0-6.394-5.231-11.577-11.682-11.577-6.453 0-11.684 5.184-11.684 11.577s5.231 11.579 11.684 11.579c2.113 0 4.094-0.561 5.805-1.533l9.693 9.574c1.092 1.080 2.873 1.068 3.981-0.027 1.105-1.098 1.117-2.863 0.027-3.945zM9.441 11.577c0-4.146 3.391-7.507 7.576-7.507 4.184 0 7.574 3.361 7.574 7.507 0 4.147-3.391 7.507-7.574 7.507-4.186 0-7.576-3.36-7.576-7.507z" style="fill:white;"></path>
# </svg>
# </span>
# </button>
# </div>
# </div>
# </div>
# <div class="mh-tw-right-col">
# <div class="mh-tw-mobile-search-wrap">
# <div class="mh-mobile-search-button-wrap mh-hover-behavior">
# <button class="mh-mobile-search-button" tabindex="0">
# <span class="mh-search-icon-wrap">
# <svg height="32" version="1.1" viewbox="0 0 43 32" width="43" xmlns="http://www.w3.org/2000/svg">
# <path class="mh-masthead-icon" d="M36.523 27.225l-9.613-9.493c1.133-1.782 1.789-3.892 1.789-6.154 0-6.394-5.231-11.577-11.682-11.577-6.453 0-11.684 5.184-11.684 11.577s5.231 11.579 11.684 11.579c2.113 0 4.094-0.561 5.805-1.533l9.693 9.574c1.092 1.080 2.873 1.068 3.981-0.027 1.105-1.098 1.117-2.863 0.027-3.945zM9.441 11.577c0-4.146 3.391-7.507 7.576-7.507 4.184 0 7.574 3.361 7.574 7.507 0 4.147-3.391 7.507-7.574 7.507-4.186 0-7.576-3.36-7.576-7.507z"></path>
# </svg>
# </span>
# <span>
# <span class="mh-mobile-search-label">Search</span>
# </span>
# </button>
# </div>
# </div>
# <div class="mh-tw-sign-in-wrap">
# <div class="mh-sign-in-button-wrap">
# <button aria-expanded="false" class="mh-si-button" tabindex="0">
# <span class="mh-si-icon-wrap">
# <svg height="32" version="1.1" viewbox="0 0 30.5 32" width="30.5" x="0px" xml:space="preserve" xmlns="//www.w3.org/2000/svg" xmlns:xlink="//www.w3.org/1999/xlink" y="0px">
# <path class="mh-si-icon" d="M15.6,0c4.3,0,7.8,3.5,7.8,7.7c0,4.3-3.5,7.8-7.8,7.8c-4.3,0-7.7-3.5-7.7-7.8C7.9,3.5,11.3,0,15.6,0z M30.5,32H0v-5.6c0-4.3,3.5-7.8,7.8-7.8h15c4.3,0,7.8,3.5,7.8,7.8V32z"></path></svg>
# </span>
# <span>
# <span class="mh-si-label" mh-sign-in-label="Sign In">Sign In</span>
# </span>
# </button>
# <div class="mh-ma-dropdown mh-visibly-hidden">
# <div class="mh-si-cold-state mh-text">My Account</div>
# <ul class="mh-ma-bullets mh-si-cold-state">
# <li>Place orders quickly and easily</li>
# <li>View orders and track your shipping status</li>
# <li>Enjoy members-only rewards and discounts</li>
# <li>Create and access a list of your products</li>
# </ul>
# <div class="mh-si-links-wrap">
# <a class="mh-btn mh-btn-primary mh-si-cold-state mh-sign-in-btn" href="//www.dell.com/Identity/global/LoginOrRegister/98254675-AC6F-47D9-A7E4-4537724F135D?c=us&amp;l=en&amp;r=us&amp;s=corp&amp;~ck=mn&amp;redirectUrl=">Sign In</a>
# <a class="mh-btn mh-btn-default mh-si-cold-state create-acct-btn" href="//www.dell.com/Identity/global/LoginOrRegister/98254675-AC6F-47D9-A7E4-4537724F135D?c=us&amp;l=en&amp;r=us&amp;s=corp&amp;~ck=mn&amp;redirectUrl=">Create an account</a>
# <a class="mh-si-links mh-si-cold-state" href="//dfs.dell.com/Pages/DFSHomePage.aspx?~ck=mn">Dell Financial Services</a>
# <a class="mh-si-links mh-si-cold-state" href="//www.dell.com/Identity/global/Login/75814991-4252-4cc4-a977-670cc21309a7?~ck=mn">Premier Sign In</a>
# <a class="mh-si-links mh-si-cold-state" href="//www.dell.com/content/public/xdbredirect.aspx?link=global:nav:partnerprogram:signin&amp;~ck=mn">Partner Program Sign In</a>
# <a class="mh-si-links mh-si-hot-state mh-first" href="//www.dell.com/en-us/myaccount/?~ck=mn">My Account</a>
# <a class="mh-si-links mh-si-hot-state" href="//www.dell.com/support/orders?~ck=mn">Order Status</a>
# <a class="mh-si-links mh-si-hot-state" href="//www.dell.com/support/mps/?~ck=mn">My Products</a>
# <a class="mh-si-links mh-si-hot-state" href="//dfs.dell.com/Pages/DFSHomePage.aspx?~ck=mn">Dell Financial Services</a>
# <a class="mh-si-links mh-si-hot-state" href="//www.dell.com/en-us/shop/dell-rewards-program/cp/dell-rewards-program?~ck=mn">Dell Rewards</a>
# <a class="mh-si-links mh-si-hot-state" href="//www.dell.com/Identity/global/Login/75814991-4252-4cc4-a977-670cc21309a7?~ck=mn">Premier Sign In</a>
# <a class="mh-si-links mh-si-hot-state" href="//www.dell.com/content/public/xdbredirect.aspx?link=global:nav:partnerprogram:signin&amp;~ck=mn">Partner Program Sign In</a>
# <a class="mh-btn mh-btn-default mh-si-hot-state mh-sign-out-btn" href="//www.dell.com/en-us/security/authentication/signoutreturntoreferrer?~ck=mn">Sign Out</a>
# </div>
# </div>
# </div>
# </div>
# <div class="mh-tw-cart-wrap">
# <div class="mh-cart-trigger-wrap" id="mh-cart" mh-show-flyout="mh-show-flyout" tabindex="0">
# <a aria-label="Cart" class="mh-cart-trigger mh-hover-behavior" data-show-cart-flyout="True" href="https://www.dell.com/en-us/cart/allcarts?~ck=mn" role="button">
# <span class="mh-ct-icon-wrap" mh-bubble-count="" mh-show-bubble="false">
# <svg height="32" version="1.1" viewbox="0 0 43 32" width="43" x="0px" xml:space="preserve" xmlns="//www.w3.org/2000/svg" xmlns:xlink="//www.w3.org/1999/xlink" y="0px">
# <path class="cf-masthead-icon" d="M36.6,17.4l5-12c0.1-0.3,0.1-0.6-0.1-0.8c-0.2-0.2-0.5-0.4-0.8-0.4l-30.3,0L9,0.8C8.9,0.8,8.9,0,7.2,0H3.8c-1,0-2-0.2-2.6,1C1.1,1.2,1,1.4,1,1.7v0c0,0,0,0,0,0c0,0.2,0.1,0.5,0.1,0.7c0.1,0.2,0.2,0.3,0.3,0.5c0,0,0,0.1,0.1,0.1c0.4,0.5,1,0.9,1.8,0.9h3.5c0,0,0,0,0,0l10.5,20.7c-1.4,0.6-2.4,2-2.4,3.6c0,2.1,1.7,3.9,3.9,3.9c2.1,0,3.9-1.7,3.9-3.9c0-0.2,0-1.9,0-2.1l8.5,0c0,0.1,0,1.9,0,2.1c0,2.1,1.7,3.9,3.9,3.9c2.1,0,3.9-1.7,3.9-3.9c0-1.7-1.2-3.2-2.8-3.7c-0.1,0-0.1-0.1-0.2-0.1c-0.2-0.7-0.8-1.2-1.5-1.2l-14.3,0l-2.7-5.2l18.2,0C36.1,17.9,36.4,17.7,36.6,17.4L36.6,17.4z"></path></svg>
# </span>
# <span>Cart</span>
# </a>
# <div class="mh-ct-dropdown-wrap">
# <div class="mh-ct-home-dropdown mh-ct-loading" hm-absent-cartitem="Your cart is empty" hm-item-plural="items" hm-item-singular="item">
# <div class="mh-shadow-box"></div>
# <div class="mh-ct-dd-content mh-ct-dd-show">
# <span class="mh-ct-dd-cartInfo"></span>
# <ul class="mh-ct-carts-wrap">
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="mh-tw-country-wrap mh-hover-behavior">
# <div class="mh-top-country" component="locale">
# <div class="mh-locale mh-locale-top" id="mh-top-countryselector">
# <div class="mh-top-flag-icon" id="mh-top-countrytoggle">
# <div>
# <img alt="USA" src="//i.dell.com/images/global/masthead/smlflags/us.gif"/>
# </div>
# <div class="mh-top-country-code">USA</div>
# </div>
# <ul class="mh-locale-menu mh-locale-menu-top" data-country-service="//www.dell.com/csbapi/masthead/countrylist/us/en" id="mh-top-countrylist"></ul>
# </div>
# </div>
# </div>
# <div class="mh-tw-hamburger-wrap">
# <div class="mh-tw-hamburger-button-wrap">
# <button class="mh-hamburger-trigger">
# <span class="mh-hb-icon-wrap">
# <svg height="32" version="1.1" viewbox="0 0 43 32" width="32" x="0px" xml:space="preserve" xmlns="//www.w3.org/2000/svg" xmlns:xlink="//www.w3.org/1999/xlink" y="0px">
# <path class="mh-hamburger-icon" d="M3.393 0h35.88v6.347h-35.88zM3.393 12.826h35.88v6.347h-35.88zM3.393 25.653h35.88v6.347h-35.88z"></path></svg>
# </span>
# <span class="mh-mobile-hamburger-label">Menu</span>
# </button>
# </div>
# </div>
# </div>
# </div>
# <div class="mh-shadow-line-blue">
# <div class="mh-container mh-shadow"></div>
# </div>
# <div class="mh-site-nav-wrap mh-container">
# <nav aria-label="Main" class="mh-no-js" role="navigation">
# <a class="mh-skip-main" href="#mh-skip-nav-target">Skip to main content</a>
# <ul class="mh-site-nav">
# <li class="mh-list-item-2" data-testid="header-navigation-menu-t1-item">
# <button aria-haspopup="true" class="mh-list-item-2-trigger" id="l1" tabindex="0">
#                     Products
#                 </button>
# <ul aria-labelledby="l1" class="mh-tier2 mh-dropdown-menu" data-testid="header-navigation-menu-t2-item">
# <li class="mh-level-2-children mh-img-menu-trigger">
# <a class="mh-tier3-link mh-has-children mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="javascript:;" id="l1_1" tabindex="0">
# <span class="mh-has-content"> Laptops</span>
# </a>
# <ul aria-labelledby="l1_1" class="mh-tier3 mh-img-menu-wrap" data-testid="header-navigation-menu-t3-item">
# <li class="mh-image-item mh-nav-hover">
# <a data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/shop/scc/sc/laptops?~ck=mn" tabindex="0">
# <img alt="View all Laptops for Home" height="75" mh-lazy-prior="low" mh-lazy-src="//i.dell.com/sites/csimages/Merchandizing_Imagery/all/26918-notebook-xps-13-9300-prem-115x75.png" onerror="this.style.display = 'none'" src="data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg' %3E%3Crect x='1' y='1' width='-3' height='-3'/%3E%3C/svg%3E" width="115"/>
# <span class="mh-img-caption">For Home</span>
# <span class="mh-img-subtitle">View all Laptops for Home</span>
# </a>
# </li>
# <li class="mh-image-item mh-nav-hover">
# <a data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/work/shop/scc/sc/laptops?~ck=mn" tabindex="0">
# <img alt="View all Laptops for Business" height="75" mh-lazy-prior="low" mh-lazy-src="//i.dell.com/sites/csimages/Banner_Imagery/en/mh_forwork_laptops_115x75.png" onerror="this.style.display = 'none'" src="data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg' %3E%3Crect x='1' y='1' width='-3' height='-3'/%3E%3C/svg%3E" width="115"/>
# <span class="mh-img-caption">For Business</span>
# <span class="mh-img-subtitle">View all Laptops for Business</span>
# </a>
# </li>
# </ul>
# </li>
# <li class="mh-level-2-children mh-img-menu-trigger">
# <a class="mh-tier3-link mh-has-children mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="javascript:;" id="l1_2" tabindex="0">
# <span class="mh-has-content"> Desktops &amp; All-in-One PCs</span>
# </a>
# <ul aria-labelledby="l1_2" class="mh-tier3 mh-img-menu-wrap" data-testid="header-navigation-menu-t3-item">
# <li class="mh-image-item mh-nav-hover">
# <a data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/shop/scc/sc/desktops?~ck=mn" tabindex="0">
# <img alt="View all Desktops &amp; All-in-One PCs for Home" height="75" mh-lazy-prior="low" mh-lazy-src="//i.dell.com/sites/csimages/Banner_Imagery/en/mh_forhome_desktops-xps-8940-non-odd-bk-115x75.png" onerror="this.style.display = 'none'" src="data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg' %3E%3Crect x='1' y='1' width='-3' height='-3'/%3E%3C/svg%3E" width="115"/>
# <span class="mh-img-caption">For Home</span>
# <span class="mh-img-subtitle">View all Desktops &amp; All-in-One PCs for Home</span>
# </a>
# </li>
# <li class="mh-image-item mh-nav-hover">
# <a data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/work/shop/scc/sc/desktops-n-workstations?~ck=mn" tabindex="0">
# <img alt="View all Desktops &amp; All-in-One PCs for Business" height="75" mh-lazy-prior="low" mh-lazy-src="//i.dell.com/sites/csimages/Banner_Imagery/en/mh_forwork_desktops_optiplex-7080_vostro-3681_115x75.png" onerror="this.style.display = 'none'" src="data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg' %3E%3Crect x='1' y='1' width='-3' height='-3'/%3E%3C/svg%3E" width="115"/>
# <span class="mh-img-caption">For Business</span>
# <span class="mh-img-subtitle">View all Desktops &amp; All-in-One PCs for Business</span>
# </a>
# </li>
# </ul>
# </li>
# <li class="mh-level-2-children mh-img-menu-trigger">
# <a class="mh-tier3-link mh-has-children mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="javascript:;" id="l1_3" tabindex="0">
# <span class="mh-has-content"> Tablets &amp; 2-in-1 Laptops</span>
# </a>
# <ul aria-labelledby="l1_3" class="mh-tier3 mh-img-menu-wrap" data-testid="header-navigation-menu-t3-item">
# <li class="mh-image-item mh-nav-hover">
# <a data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/shop/scc/sc/2-in-1-laptop?~ck=mn" tabindex="0">
# <img alt="View all 2-in-1 Laptops for Home" height="75" mh-lazy-prior="low" mh-lazy-src="//i.dell.com/sites/csimages/Merchandizing_Imagery/all/2404-xp7390t-115x75.png" onerror="this.style.display = 'none'" src="data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg' %3E%3Crect x='1' y='1' width='-3' height='-3'/%3E%3C/svg%3E" width="115"/>
# <span class="mh-img-caption">For Home</span>
# <span class="mh-img-subtitle">View all 2-in-1 Laptops for Home</span>
# </a>
# </li>
# <li class="mh-image-item mh-nav-hover">
# <a data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/work/shop/scc/sc/dell-tablets?~ck=mn" tabindex="0">
# <img alt="View all Tablets &amp; 2-in-1 Laptops for Business" height="75" mh-lazy-prior="low" mh-lazy-src="//i.dell.com/sites/csimages/Banner_Imagery/en/mh_forwork_tablets_2in1laptops_115x75.png" onerror="this.style.display = 'none'" src="data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg' %3E%3Crect x='1' y='1' width='-3' height='-3'/%3E%3C/svg%3E" width="115"/>
# <span class="mh-img-caption">For Business</span>
# <span class="mh-img-subtitle">View all Tablets &amp; 2-in-1 Laptops for Business</span>
# </a>
# </li>
# </ul>
# </li>
# <li class="mh-level-2-children mh-img-menu-trigger">
# <a class="mh-tier3-link mh-has-children mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="javascript:;" id="l1_4" tabindex="0">
# <span class="mh-has-content"> Gaming</span>
# </a>
# <ul aria-labelledby="l1_4" class="mh-tier3 mh-img-menu-wrap" data-testid="header-navigation-menu-t3-item">
# <li class="mh-image-item mh-nav-hover">
# <a data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/gaming/alienware?cs=19&amp;~ck=mn" tabindex="0">
# <img alt="View all Gaming Laptops &amp; Desktops" height="75" mh-lazy-prior="low" mh-lazy-src="//i.dell.com/sites/csimages/Merchandizing_Imagery/all/2404-awaurorar9_awm15r2_gy-115x75.png" onerror="this.style.display = 'none'" src="data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg' %3E%3Crect x='1' y='1' width='-3' height='-3'/%3E%3C/svg%3E" width="115"/>
# <span class="mh-img-caption">Alienware PCs</span>
# <span class="mh-img-subtitle">View all Gaming Laptops &amp; Desktops</span>
# </a>
# </li>
# <li class="mh-image-item mh-nav-hover">
# <a data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/shop/gaming-and-games/cp/game?~ck=mn" tabindex="0">
# <img alt="View all Gaming PCs, Consoles &amp; Accessories" height="75" mh-lazy-prior="low" mh-lazy-src="//i.dell.com/sites/content/DellMicroContent/Responsive_Images/english/_values/mast-gaming-consoles2.png" onerror="this.style.display = 'none'" src="data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg' %3E%3Crect x='1' y='1' width='-3' height='-3'/%3E%3C/svg%3E" width="115"/>
# <span class="mh-img-caption">Dell Gaming</span>
# <span class="mh-img-subtitle">View all Gaming PCs, Consoles &amp; Accessories</span>
# </a>
# </li>
# </ul>
# </li>
# <li>
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="//www.dell.com/en-us/work/shop/scc/sc/workstations?~ck=mn" tabindex="0">
#             Workstations
#         </a>
# </li>
# <li>
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="//www.dell.com/en-us/work/shop/scc/sc/cloud-client?~ck=mn" tabindex="0">
#             Thin Clients
#         </a>
# </li>
# <li>
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="//www.dell.com/en-us/work/shop/servers/cp/servers-storage-networking?~ck=mn" tabindex="0">
#             Servers &amp; Storage
#         </a>
# </li>
# <li class="mh-level-2-children mh-img-menu-trigger">
# <a class="mh-tier3-link mh-has-children mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="javascript:;" id="l1_5" tabindex="0">
# <span class="mh-has-content"> Networking</span>
# </a>
# <ul aria-labelledby="l1_5" class="mh-tier3 mh-img-menu-wrap" data-testid="header-navigation-menu-t3-item">
# <li class="mh-image-item mh-nav-hover">
# <a data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/shop/networking/ac/4011?~ck=mn" tabindex="0">
# <img alt="View all Networking for Home" height="75" mh-lazy-prior="low" mh-lazy-src="//i.dell.com/sites/content/DellMicroContent/Responsive_Images/english/_values/mast-forhome-networking3.png" onerror="this.style.display = 'none'" src="data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg' %3E%3Crect x='1' y='1' width='-3' height='-3'/%3E%3C/svg%3E" width="115"/>
# <span class="mh-img-caption">For Home</span>
# <span class="mh-img-subtitle">View all Networking for Home</span>
# </a>
# </li>
# <li class="mh-image-item mh-nav-hover">
# <a data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/work/shop/scc/sc/networking-products?~ck=mn" tabindex="0">
# <img alt="View all Networking for Business" height="75" mh-lazy-prior="low" mh-lazy-src="//i.dell.com/sites/content/DellMicroContent/Responsive_Images/english/_values/mast-forwork-networking2.png" onerror="this.style.display = 'none'" src="data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg' %3E%3Crect x='1' y='1' width='-3' height='-3'/%3E%3C/svg%3E" width="115"/>
# <span class="mh-img-caption">For Business</span>
# <span class="mh-img-subtitle">View all Networking for Business</span>
# </a>
# </li>
# </ul>
# </li>
# <li class="mh-level-2-children mh-img-menu-trigger">
# <a class="mh-tier3-link mh-has-children mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="javascript:;" id="l1_6" tabindex="0">
# <span class="mh-has-content"> Monitors</span>
# </a>
# <ul aria-labelledby="l1_6" class="mh-tier3 mh-img-menu-wrap" data-testid="header-navigation-menu-t3-item">
# <li class="mh-image-item mh-nav-hover">
# <a data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/shop/monitors-monitor-accessories/ac/4009?~ck=mn" tabindex="0">
# <img alt="View all Monitors for Home" height="75" mh-lazy-prior="low" mh-lazy-src="//i.dell.com/sites/csimages/Banner_Imagery/en/mh_forhome_monitors_115x75.png" onerror="this.style.display = 'none'" src="data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg' %3E%3Crect x='1' y='1' width='-3' height='-3'/%3E%3C/svg%3E" width="115"/>
# <span class="mh-img-caption">For Home</span>
# <span class="mh-img-subtitle">View all Monitors for Home</span>
# </a>
# </li>
# <li class="mh-image-item mh-nav-hover">
# <a data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/work/shop/monitors-monitor-accessories/ac/4009?~ck=mn" tabindex="0">
# <img alt="View all Monitors for Business" height="75" mh-lazy-prior="low" mh-lazy-src="//i.dell.com/sites/csimages/Banner_Imagery/en/mh_forwork_monitors_115x75.png" onerror="this.style.display = 'none'" src="data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg' %3E%3Crect x='1' y='1' width='-3' height='-3'/%3E%3C/svg%3E" width="115"/>
# <span class="mh-img-caption">For Business</span>
# <span class="mh-img-subtitle">View all Monitors for Business</span>
# </a>
# </li>
# </ul>
# </li>
# <li class="mh-level-2-children mh-img-menu-trigger">
# <a class="mh-tier3-link mh-has-children mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="javascript:;" id="l1_7" tabindex="0">
# <span class="mh-has-content"> Printers, Ink &amp; Toner</span>
# </a>
# <ul aria-labelledby="l1_7" class="mh-tier3 mh-img-menu-wrap" data-testid="header-navigation-menu-t3-item">
# <li class="mh-image-item mh-nav-hover">
# <a data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/shop/printers-ink-toner/ac/4014?~ck=mn" tabindex="0">
# <img alt="View all Printers &amp; Ink for Home" height="75" mh-lazy-prior="low" mh-lazy-src="//i.dell.com/sites/csimages/Merchandizing_Imagery/all/ecotank_et-3760_transparent2.png" onerror="this.style.display = 'none'" src="data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg' %3E%3Crect x='1' y='1' width='-3' height='-3'/%3E%3C/svg%3E" width="115"/>
# <span class="mh-img-caption">For Home</span>
# <span class="mh-img-subtitle">View all Printers &amp; Ink for Home</span>
# </a>
# </li>
# <li class="mh-image-item mh-nav-hover">
# <a data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/work/shop/printers-ink-toner/ac/4014?~ck=mn" tabindex="0">
# <img alt="View all Printers, Ink &amp; Toner for Business" height="75" mh-lazy-prior="low" mh-lazy-src="//i.dell.com/sites/csimages/Banner_Imagery/en/mh_forwork_printers_115x75.png" onerror="this.style.display = 'none'" src="data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg' %3E%3Crect x='1' y='1' width='-3' height='-3'/%3E%3C/svg%3E" width="115"/>
# <span class="mh-img-caption">For Business</span>
# <span class="mh-img-subtitle">View all Printers, Ink &amp; Toner for Business</span>
# </a>
# </li>
# </ul>
# </li>
# <li class="mh-level-2-children mh-img-menu-trigger">
# <a class="mh-tier3-link mh-has-children mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="javascript:;" id="l1_8" tabindex="0">
# <span class="mh-has-content"> Software</span>
# </a>
# <ul aria-labelledby="l1_8" class="mh-tier3 mh-img-menu-wrap" data-testid="header-navigation-menu-t3-item">
# <li class="mh-image-item mh-nav-hover">
# <a data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/shop/software/ac/4020?~ck=mn" tabindex="0">
# <img alt="View all Software for Home" height="75" mh-lazy-prior="low" mh-lazy-src="//i.dell.com/sites/content/DellMicroContent/Responsive_Images/english/_values/mast-forhome-software2.png" onerror="this.style.display = 'none'" src="data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg' %3E%3Crect x='1' y='1' width='-3' height='-3'/%3E%3C/svg%3E" width="115"/>
# <span class="mh-img-caption">For Home</span>
# <span class="mh-img-subtitle">View all Software for Home</span>
# </a>
# </li>
# <li class="mh-image-item mh-nav-hover">
# <a data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/work/shop/software/ac/4020?~ck=mn" tabindex="0">
# <img alt="View all Software for Business" height="75" mh-lazy-prior="low" mh-lazy-src="//i.dell.com/sites/csimages/Banner_Imagery/en/mh_forwork_software_115x75.png" onerror="this.style.display = 'none'" src="data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg' %3E%3Crect x='1' y='1' width='-3' height='-3'/%3E%3C/svg%3E" width="115"/>
# <span class="mh-img-caption">For Business</span>
# <span class="mh-img-subtitle">View all Software for Business</span>
# </a>
# </li>
# </ul>
# </li>
# <li class="mh-level-2-children mh-img-menu-trigger">
# <a class="mh-tier3-link mh-has-children mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="javascript:;" id="l1_9" tabindex="0">
# <span class="mh-has-content"> Electronics &amp; Accessories</span>
# </a>
# <ul aria-labelledby="l1_9" class="mh-tier3 mh-img-menu-wrap" data-testid="header-navigation-menu-t3-item">
# <li class="mh-image-item mh-nav-hover">
# <a data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/shop/accessories?~ck=mn" tabindex="0">
# <img alt="View all Electronics &amp; Accessories for Home" height="75" mh-lazy-prior="low" mh-lazy-src="//i.dell.com/sites/csimages/Banner_Imagery/en/mh_forhome_ena_115x75.png" onerror="this.style.display = 'none'" src="data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg' %3E%3Crect x='1' y='1' width='-3' height='-3'/%3E%3C/svg%3E" width="115"/>
# <span class="mh-img-caption">For Home</span>
# <span class="mh-img-subtitle">View all Electronics &amp; Accessories for Home</span>
# </a>
# </li>
# <li class="mh-image-item mh-nav-hover">
# <a data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/work/shop/accessories?~ck=mn" tabindex="0">
# <img alt="View all Electronics &amp; Accessories for Business" height="75" mh-lazy-prior="low" mh-lazy-src="//i.dell.com/sites/csimages/Banner_Imagery/en/mh_forwork_ena_115x75.png" onerror="this.style.display = 'none'" src="data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg' %3E%3Crect x='1' y='1' width='-3' height='-3'/%3E%3C/svg%3E" width="115"/>
# <span class="mh-img-caption">For Business</span>
# <span class="mh-img-subtitle">View all Electronics &amp; Accessories for Business</span>
# </a>
# </li>
# </ul>
# </li>
# <li>
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="//www.dell.com/en-us/work/shop/scc/sc/gateways-embedded-pcs?~ck=mn" tabindex="0">
#             Gateways &amp; Embedded PCs
#         </a>
# </li>
# </ul>
# <a aria-hidden="true" class="mh-close-focus" href="javascript:;" tabindex="-1"></a>
# </li>
# <li class="mh-list-item-2" data-testid="header-navigation-menu-t1-item">
# <button aria-haspopup="true" class="mh-list-item-2-trigger" id="l2" tabindex="0">
#                     Solutions
#                 </button>
# <ul aria-labelledby="l2" class="mh-tier2 mh-dropdown-menu" data-testid="header-navigation-menu-t2-item">
# <li>
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="//www.delltechnologies.com/en-us/solutions/index.htm?~ck=mn" tabindex="0">
#             View All Solutions
#         </a>
# </li>
# <li class="mh-level-2-children mh-list-menu-trigger">
# <a class="mh-tier3-link mh-has-children mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="javascript:;" id="l2_1" tabindex="0">
# <span class="mh-has-content"> Industries</span>
# </a>
# <ul aria-labelledby="l2_1" class="mh-tier3 mh-list-menu-wrap" data-testid="header-navigation-menu-t3-item">
# <li class="mh-list-menu-trigger">
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t3-item" href="//www.delltechnologies.com/en-us/industry/federal/federal-government-it.htm?~ck=mn">Federal Government</a>
# </li>
# <li class="mh-list-menu-trigger">
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t3-item" href="//www.delltechnologies.com/en-us/industry/healthcare-it/index.htm?~ck=mn">Healthcare</a>
# </li>
# <li class="mh-list-menu-trigger">
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t3-item" href="//www.delltechnologies.com/en-us/industry/higher-education/index.htm?~ck=mn">Higher Education</a>
# </li>
# <li class="mh-list-menu-trigger">
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t3-item" href="//www.delltechnologies.com/en-us/industry/education/index.htm?~ck=mn">K-12 Education</a>
# </li>
# <li class="mh-list-menu-trigger">
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t3-item" href="//www.delltechnologies.com/en-us/oem/index.htm?~ck=mn">Original Equipment Manufacturers</a>
# </li>
# <li class="mh-list-menu-trigger">
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t3-item" href="//www.delltechnologies.com/en-us/industry/retail-it/index.htm?~ck=mn">Retail</a>
# </li>
# <li class="mh-list-menu-trigger">
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t3-item" href="//www.delltechnologies.com/en-us/industry/state-local-government/index.htm?~ck=mn">State &amp; Local Government</a>
# </li>
# <li class="mh-list-menu-trigger">
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t3-item" href="//www.delltechnologies.com/en-us/oem/telecommunications.htm?~ck=mn">Telecommunications, Media &amp; Entertainment</a>
# </li>
# </ul>
# </li>
# <li class="mh-level-2-children mh-list-menu-trigger">
# <a class="mh-tier3-link mh-has-children mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="javascript:;" id="l2_2" tabindex="0">
# <span class="mh-has-content"> Small Business</span>
# </a>
# <ul aria-labelledby="l2_2" class="mh-tier3 mh-list-menu-wrap" data-testid="header-navigation-menu-t3-item">
# <li class="mh-list-menu-trigger">
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/work/shop/dell-small-business/cp/small-business-central?~ck=mn">Small Business Solutions</a>
# </li>
# <li class="mh-list-menu-trigger">
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/work/shop/dell-small-business/cp/dell-expert-network?~ck=mn">Dell Expert Network</a>
# </li>
# <li class="mh-list-menu-trigger">
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/work/shop/dell-small-business/cp/professional-associations-and-non-profits?~ck=mn">Dell Professional Associations &amp; Non-Profits</a>
# </li>
# <li class="mh-list-menu-trigger">
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/work/shop/dell-small-business/cp/dell-for-entrepreneurs?~ck=mn">Dell for Entrepreneurs</a>
# </li>
# <li class="mh-list-menu-trigger">
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/work/shop/dell-small-business/cp/dell-women-entrepreneur-network?~ck=mn">Dell Women's Entrepreneur Network</a>
# </li>
# <li class="mh-list-menu-trigger">
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t3-item" href="//www.dell.com/en-us/work/shop/dell-small-business/cp/partner-outreach-program?~ck=mn">Small Business Partner Outreach Program</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="//www.delltechnologies.com/en-us/big-data/index.htm?~ck=mn" tabindex="0">
#             Big Data
#         </a>
# </li>
# <li>
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="//www.delltechnologies.com/en-us/cloud/hybrid-cloud-computing/index.htm?~ck=mn" tabindex="0">
#             Cloud
#         </a>
# </li>
# <li class="mh-level-2-children mh-list-menu-trigger">
# <a class="mh-tier3-link mh-has-children mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="//www.delltechnologies.com/en-us/solutions/index.htm?~ck=mn" id="l2_3" tabindex="0">
# <span class="mh-has-content"> Data Center</span>
# </a>
# <ul aria-labelledby="l2_3" class="mh-tier3 mh-list-menu-wrap" data-testid="header-navigation-menu-t3-item">
# <li class="mh-list-menu-trigger">
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t3-item" href="//www.delltechnologies.com/en-us/servers/index.htm?~ck=mn">Data Center - Servers</a>
# </li>
# <li class="mh-list-menu-trigger">
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t3-item" href="//www.delltechnologies.com/en-us/storage/data-storage.htm?~ck=mn">Data Center - Storage</a>
# </li>
# <li class="mh-list-menu-trigger">
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t3-item" href="//www.delltechnologies.com/en-us/networking/index.htm?~ck=mn">Data Center - Networking</a>
# </li>
# <li class="mh-list-menu-trigger">
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t3-item" href="//www.delltechnologies.com/en-us/servers/modular-infrastructure/index.htm?~ck=mn">Data Center - Modular Infrastructure</a>
# </li>
# <li class="mh-list-menu-trigger">
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t3-item" href="//www.delltechnologies.com/en-us/converged-infrastructure/index.htm?~ck=mn">Converged Infrastructure</a>
# </li>
# <li class="mh-list-menu-trigger">
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t3-item" href="//www.delltechnologies.com/en-us/solutions/high-performance-computing/index.htm?~ck=mn">High Performance Computing</a>
# </li>
# <li class="mh-list-menu-trigger">
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t3-item" href="//www.delltechnologies.com/en-us/solutions/openmanage/index.htm?~ck=mn">OpenManage Systems Management</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="//www.delltechnologies.com/en-us/dell-hybrid-client/index.htm?~ck=mn" tabindex="0">
#             Dell Hybrid Client
#         </a>
# </li>
# <li>
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="//www.delltechnologies.com/en-us/solutions/internet-of-things.htm?~ck=mn" tabindex="0">
#             Internet of Things
#         </a>
# </li>
# <li>
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="//www.dell.com/en-us/work/shop/pc-as-a-service-for-business/cp/pcaas?~ck=mn" tabindex="0">
#             PC as a Service (PCaaS) for Business
#         </a>
# </li>
# <li>
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="//education.dellemc.com/content/emc/en-us/home.html?~ck=mn" tabindex="0">
#             Training &amp; Certification
#         </a>
# </li>
# <li>
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="//www.delltechnologies.com/en-us/unified-workspace/index.htm?~ck=mn" tabindex="0">
#             Unified Workspace
#         </a>
# </li>
# <li>
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="//www.delltechnologies.com/en-us/solutions/vdi/index-it.htm?~ck=mn" tabindex="0">
#             Virtual Desktop Infrastructure
#         </a>
# </li>
# </ul>
# <a aria-hidden="true" class="mh-close-focus" href="javascript:;" tabindex="-1"></a>
# </li>
# <li class="mh-list-item-2" data-testid="header-navigation-menu-t1-item">
# <button aria-haspopup="true" class="mh-list-item-2-trigger" id="l3" tabindex="0">
#                     Services
#                 </button>
# <ul aria-labelledby="l3" class="mh-tier2 mh-dropdown-menu" data-testid="header-navigation-menu-t2-item">
# <li>
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="//www.delltechnologies.com/en-us/services/index.htm?~ck=mn" tabindex="0">
#             View All Services
#         </a>
# </li>
# <li>
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="//renewals.dell.com/?~ck=mn" tabindex="0">
#             Warranty Extension
#         </a>
# </li>
# <li>
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="//www.dell.com/en-us/shop/servicesforhome/cp/servicesforhome?~ck=mn" tabindex="0">
#             Services for Home
#         </a>
# </li>
# <li>
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="//www.dell.com/en-us/work/shop/dell-small-business/cp/servicesforsmallbusiness?~ck=mn" tabindex="0">
#             Services for Small Business
#         </a>
# </li>
# <li>
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="//www.delltechnologies.com/en-us/services/support-services/index.htm?~ck=mn" tabindex="0">
#             Support Services for Commercial
#         </a>
# </li>
# <li>
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="//www.delltechnologies.com/en-us/services/consulting-services/index.htm?~ck=mn" tabindex="0">
#             Consulting
#         </a>
# </li>
# <li>
# <a class="mh-tier3-link mh-nav-hover" data-testid="header-navigation-menu-t1-sub-item" href="//www.delltechnologies.com/en-us/services/managed-services/index.htm?~ck=mn" tabindex="0">
#             Managed Services
#         </a>
# </li>
# <li>
# ...
# <h2>BLACK FRIDAY</h2>
# <p class="hpg-tagline">SAVE ON YOUR ANYWHERE OFFICE</p>
# </a>
# <a aria-label="BLACK FRIDAY" class="order-image" href="http://deals.dell.com/en-us/work?ref=hpg_two_up1_right_image_cta1">
# <div>
# <img alt="BLACK FRIDAY" class="hpg-img-2up" hp-lazy-src="https://i.dell.com/sites/csimages/UberHomePage_Imagery/all/377485_us_cs_co_dir_fy21q4W1_site_BF-EA-CSB-10-29--11-11_800x400-3-Copy.jpg" onerror="this.src = '...'; this.onerror= null;" sizes="(min-width: 768px) 50vw, 100vw" src="//afcs.dellcdn.com/csb/homepage/bundles/1.0.1.5739/images/pixel.gif"/>
# </div>
# </a>
# <p class="hpg-text-block order-text-block">
#                 Move your business forward with the right tech at up to 40% off.
#             </p>
# <div class="hpg-sect-link-wrap order-link-wrap">
# <a class="hpg-btn" href="http://deals.dell.com/en-us/work?ref=hpg_two_up1_right_cta1">PC Deals</a>
# </div>
# </div>
# </div>
# </div>
# <style>[component=footer] *,[component=valueprop] *{-webkit-box-sizing:border-box;box-sizing:border-box}[component=footer] a,[component=valueprop] a{text-decoration:none}[component=footer] .mh-container,[component=valueprop] .mh-container{margin-right:auto;margin-left:auto;padding-left:15px;padding-right:15px;width:100%}@media only screen and (min-width:991px){[component=footer] .mh-container,[component=valueprop] .mh-container{width:970px}}@media only screen and (min-width:1200px){[component=footer] .mh-container,[component=valueprop] .mh-container{width:1170px}}[component=locale].mh-top-country{position:relative}[component=locale] #mh-footer-country-toggle{white-space:nowrap;color:#444}[component=locale] .mh-locale.mh-locale-top img{vertical-align:inherit}[component=locale] .mh-locale.mh-locale-top ul{height:250px;min-width:268px;width:268px;overflow-y:scroll;right:0;top:25px}[component=locale] .mh-locale.mh-local-bottom{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-align:start;-ms-flex-align:start;align-items:flex-start}[component=locale] .mh-locale.mh-local-bottom>div:nth-child(1){cursor:pointer;margin-bottom:0}[component=locale] .mh-locale.mh-local-bottom>div:nth-child(1)>div{padding-top:2px;font-size:14px;height:22px;display:-webkit-inline-box;display:-ms-inline-flexbox;display:inline-flex;word-break:keep-all}[component=locale] .mh-locale.mh-local-bottom>div:nth-child(1) img{width:18px;margin-top:4px;margin-right:3px;margin-left:2px;height:11px}[component=locale] .mh-locale.mh-local-bottom>div:nth-child(1) svg{width:16px;fill:currentColor;-webkit-transform:rotate(90deg);transform:rotate(90deg);margin-left:3px}[component=locale] .mh-locale.mh-local-bottom>div:nth-child(1) ul{-webkit-margin-before:-290px;margin-block-start:-290px;margin-top:-290px;min-width:268px;width:268px;overflow-y:scroll;float:left;top:35px;height:250px}[component=locale] .mh-locale.mh-local-bottom>div:nth-child(2){margin-left:5px;margin-right:5px}[component=locale] .mh-locale.mh-local-bottom>div:nth-child(3)>div:nth-child(1){font-size:14px;height:22px;max-height:24px;word-break:keep-all;cursor:pointer;display:-webkit-inline-box;display:-ms-inline-flexbox;display:inline-flex;padding-top:2px}[component=locale] .mh-locale.mh-local-bottom>div:nth-child(3)>div:nth-child(1) span{display:inline-block;margin-left:5px}[component=locale] .mh-locale.mh-local-bottom>div:nth-child(3)>div:nth-child(2) ul{overflow-y:hidden;position:absolute;margin:0 auto;width:auto;bottom:27px;left:-10px}[component=locale] .mh-locale{font-size:14px;word-break:keep-all;-ms-user-select:none;user-select:none;-webkit-user-select:none;-moz-user-select:none}[component=locale] .mh-locale a{display:block;padding:3px 10px;clear:both;font-weight:400;font-size:14px;text-decoration:none;line-height:1.42857143;color:#444!important}[component=locale] .mh-locale a:hover{text-decoration:none;background-color:#cce7f3;color:#333}[component=locale] .mh-locale a:focus{text-decoration:none;background-color:#eee;color:#333;outline-color:#eee}[component=locale] .mh-locale .modal-container{position:relative}[component=locale] .mh-locale ul{display:none;position:absolute;background-color:#fff;border-bottom:1px solid rgba(0,0,0,.15);border-left:1px solid rgba(0,0,0,.15);border-right:none;-webkit-box-shadow:rgba(0,0,0,.176) 0 6px 12px 0;box-shadow:rgba(0,0,0,.176) 0 6px 12px 0;color:#007db8;cursor:pointer;float:right;line-height:20px;list-style-type:none;overflow-x:hidden;-webkit-text-size-adjust:100%;-moz-text-size-adjust:100%;-ms-text-size-adjust:100%;text-size-adjust:100%;visibility:visible;z-index:999;-webkit-box-direction:normal;-webkit-tap-highlight-color:transparent;margin-bottom:0;padding-bottom:1px;padding-left:0}[component=footer] .ft-contextual-links-wrap a:visited,[component=locale] .mh-locale #mh-footer-language-toggle{color:#444}[component=locale] .mh-locale>div{-webkit-box-flex:0;-ms-flex:0 1 auto;flex:0 1 auto}[component=locale] .mh-locale #mh-footer-language-toggle>svg{wid ...
# <!-- Footer ver:1.0.1.669 -->
# <footer component="footer" id="mh-footer">
# <nav aria-label="Footer" class="ft-contextual-links-wrap">
# <div class="mh-container">
# <ul>
# <li data-testid="footer-row1-links">
# <a class="" href="https://corporate.delltechnologies.com/en-us/about-us.htm?~ck=mn">About Dell Technologies</a>
# </li>
# <li data-testid="footer-row1-links">
# <a class="" href="//jobs.dell.com/?~ck=mn">Careers</a>
# </li>
# <li data-testid="footer-row1-links">
# <a class="" href="//www.dell.com/support/home/en-us?app=community&amp;~ck=mn">Community</a>
# </li>
# <li data-testid="footer-row1-links">
# <a class="" href="https://www.delltechnologies.com/en-us/events/calendar.htm?~ck=mn">Events</a>
# </li>
# <li data-testid="footer-row1-links">
# <a class="" href="//www.dell.com/content/public/xdbredirect.aspx?link=global:nav:partners&amp;~ck=mn">Partner Program</a>
# </li>
# <li data-testid="footer-row1-links">
# <a class="" href="//www.dell.com/learn/us/en/04/premier?~ck=mn">Premier</a>
# </li>
# <li data-testid="footer-row1-links">
# <a class="" href="//www.delltechnologies.com/en-us/index.htm?~ck=mn">Dell Technologies</a>
# </li>
# <li data-testid="footer-row1-links">
# <a class="" href="//dfs.dell.com/Pages/DFSHomePage.aspx?~ck=mn">Make a Payment</a>
# </li>
# </ul>
# <div>
# <div class="footer-item-container" component="locale" id="mh-footer-country">
# <div class="mh-locale mh-local-bottom">
# <div class="modal-container" data-testid="footer-country-selector" id="mh-footer-country-selector">
# <ul class="mh-locale-menu mh-locale-menu-bottom" data-country-service="//www.dell.com/csbapi/masthead/countrylist/us/en" id="mh-footer-country-list"></ul>
# <div id="mh-footer-country-toggle">
# <img alt="United States" src="//i.dell.com/images/global/masthead/smlflags/us.gif"/>
#                     United States
#                     <svg aria-hidden="true" focusable="false" viewbox="0 0 32 32"> <path d="M21.997 16.002l-11.994-12.356v24.708z"></path> </svg>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </nav>
# <nav class="ft-legal-links-wrap" data-testid="footer-row2">
# <ul class="mh-container">
# <li data-testid="footer-row2-links">
# <a class="" href="//www.dell.com/learn/us/en/uscorp1/site-terms-of-use-copyright">© 2020 Dell</a>
# </li>
# <li data-testid="footer-row2-links">
# <a class="" href="//www.dell.com/learn/us/en/uscorp1/terms-of-sale">Terms of Sale</a>
# </li>
# <li data-testid="footer-row2-links">
# <a class="" href="//www.dell.com/learn/us/en/uscorp1/policies-privacy">Privacy Statement</a>
# </li>
# <li data-testid="footer-row2-links">
# <a class="" href="//www.dell.com/learn/us/en/uscorp1/policies-ads-and-emails">Ads &amp; Emails</a>
# </li>
# <li data-testid="footer-row2-links">
# <a class="" href="//www.dell.com/learn/us/en/uscorp1/terms">Legal &amp; Regulatory</a>
# </li>
# <li data-testid="footer-row2-links">
# <a class="" href="https://corporate.delltechnologies.com/en-us/social-impact.htm">Social Impact</a>
# </li>
# <li data-testid="footer-row2-links">
# <a class="" href="https://corporate.delltechnologies.com/en-us/social-impact/advancing-sustainability/how-to-recycle.htm">Product Recycling</a>
# </li>
# <li data-testid="footer-row2-links">
# <a class="" href="//www.dell.com/learn/us/en/uscorp1/corporate~corp-comm~en/documents~dell-california-trafficking.pdf">Anti-Slavery &amp; Human Trafficking</a>
# </li>
# <li data-testid="footer-row2-links">
# <a class="" href="//www.dell.com/support/contents/en-us/category/Contact-Information">Contact Us</a>
# </li>
# <li data-testid="footer-row2-links">
# <a class="toolbar_feedback opinionlabhtml" href="//www.dell.com/feedback">Feedback</a>
# </li>
# </ul>
# </nav>
# <div class="ft-birdseed-wrap" data-exists="False">
# <div class="mh-container">
# <div class="birdseed" data-testid="footer-bird-seed"></div>
# </div>
# </div>
# <script shared-script-required="true" type="text/javascript">if (typeof dellScriptLoader !== 'undefined') dellScriptLoader.load([{"url":"https://afcs.dellcdn.com/csb/masthead/bundles/1.0.1.669/js/countrylistscripts.min.js","order":"21","crossorigin":false}])</script>
# </footer>
# <script>
#         var Dell = Dell || {};
#         Dell.Footer = Dell.Footer || {};
#         Dell.Footer.BirdSeed = Dell.Footer.BirdSeed || {};
#         Dell.Footer.BirdSeed.setBirdSeed = (function (birdseedHtml) {
#             var divFooter = document.getElementsByClassName('ft-birdseed-wrap');
#             if (divFooter.length > 0 && birdseedHtml.length > 0) {
#                 divFooter[0].setAttribute('data-exists', 'True');
#                 var divBirdSeed = document.getElementsByClassName('birdseed');
#                 if (divBirdSeed.length > 0) {
#                     divBirdSeed[0].innerHTML = birdseedHtml;
#                 }
#             }
#             else {
#
#                 divFooter[0].setAttribute('data-exists', 'False');
#             }
#
#         });
#     </script>
# </div>
# </div>
# </div>
# <input id="language" type="hidden" value="en"/>
# <input id="country" type="hidden" value="us"/>
# <script>
#     var MasterTmsUdo = {"cj":{"cid":"","type":"","discount":"","ogid":"","currency":"","coupon":"","customerSet":"","segment":"GEN","productCategory":"","country":"US","language":"EN","revenue":"","device":"D","platform":"","promoId":"1","category":"","categoryPath":"","deals":"","family":"","productCode":"","orderCode":"","profileId":"","emailHash":"","productList":[]}};
# </script>
# <script defer="" id="contact-drawer-script" src="//afcs.dellcdn.com/csb/contact-drawer/bundles/js/contact-drawer_v1.js"></script>
# <script>
#     window.addEventListener('DOMContentLoaded',
#         function () {
#             var Dell = window.Dell || {};
#             Dell.ContactDrawer = Dell.ContactDrawer || {};
#             if (!Dell.ContactDrawer.init) { return; }
#
#             Dell.ContactDrawer.init({
#                 targetElementId: "chatDrawer",
#                 country: "us",
#                 language: "en",
#                 segment: "corp",
#                 pageId: "dell_com_homepage"
#             });
#         });
# </script>
# <div id="chatDrawer"></div>
# <script>
#             var isBoomerangEnabled = true,
#                 userContextApiUrl = "//www.dell.com/csbapi/en-us/personalization/getusercontext";
#         </script>
# <script shared-script-required="true" type="text/javascript">if (typeof dellScriptLoader !== 'undefined') dellScriptLoader.load([{"url":"//afcs.dellcdn.com/shop/scripts/global-bundle.min.39db9a6a7a3005b393edc25029976195.js","order":"0","crossorigin":true}])</script>
# <script shared-script-required="true" type="text/javascript">if (typeof dellScriptLoader !== 'undefined') dellScriptLoader.load([{"url":"//afcs.dellcdn.com/csb/homepage/bundles/1.0.1.5739/js/site.min.js","order":"2","crossorigin":false}])</script>
# <script shared-script-required="true" type="text/javascript">if (typeof dellScriptLoader !== 'undefined') dellScriptLoader.load([{"url":"//afcs.dellcdn.com/csb/homepage/bundles/1.0.1.5739/js/conversant.min.js","order":"3","crossorigin":false}])</script>
# <script type="text/javascript">if (typeof dellScriptLoader !== 'undefined') dellScriptLoader.load([{"url":"//afcs.dellcdn.com/boomerang/latest/boomerang-csb-full.min.js","order":"10","crossorigin":false}])</script>
# <script shared-script-required="true" type="text/javascript">if (typeof dellScriptLoader !== 'undefined') dellScriptLoader.load([{"url":"//nexus.dell.com/dell/stpfooter/Bootstrap.js?v=10","order":"15","crossorigin":false}])</script>
# <script type="text/javascript">if (typeof dellScriptLoader !== 'undefined') dellScriptLoader.load([{"url":"//nexus.dell.com/dell/marketing/Bootstrap.js","order":"16","crossorigin":false}])</script>
# <script>(function initLoadScripts(win) {
# 	"use strict";
# 	var scriptsArray = typeof dellScriptLoader !== "undefined"
# 		&& dellScriptLoader.hasOwnProperty("scriptsArrayCopy")
# 		&& Array.isArray(dellScriptLoader.scriptsArrayCopy())
# 			? orderArray(removeDuplicates(dellScriptLoader.scriptsArrayCopy()))
# 			: [];
#
# 	if (scriptsArray.length === 0) {
# 		return;
# 	}
#
# 	function removeDuplicates(urlArray) {
# 		var unique = {};
# 		var newArr = [];
# 		var max = urlArray.length;
#
# 		for (var i = 0; i < max; ++i) {
# 			var script = urlArray[i];
# 			//remove `.js` and everything after to make sure we are removing query parameters and/or markers to ensure no duplicates
# 			//then remove prefixes
# 			var sensitizedKey = script.url.replace(/(\.js).*/g, "").replace(/^(https:\/\/www\.|https:\/\/|\/\/|\/)/g, "");
#
# 			if (!unique[sensitizedKey]) {
# 				unique[sensitizedKey] = true;
# 				newArr.push(script);
# 			}
# 		}
#
# 		return newArr;
# 	}
#
# 	function orderArray(array) {
# 		var withOrder = array.filter(function (value, index, arr) {
# 			return value.hasOwnProperty("order");
# 		});
#
# 		var noOrder = array.filter(function (value, index, arr) {
# 			return !value.hasOwnProperty("order");
# 		});
#
# 		withOrder = withOrder.sort(function (a, b) {
# 			return a.order > b.order ? 1 : -1;
# 		});
#
# 		return [].concat(withOrder, noOrder);
# 	}
#
# 	(function loadScripts() {
# 		var scriptObject;
# 		var scriptTag;
# 		var pendingScripts = [];
# 		var firstScript = document.scripts[0];
# 		var documentHead = document.head;
# 		var fragment = document.createDocumentFragment();
# 		win.scriptOrder = [];
#
# 		// Watch scripts load in IE
# 		function stateChange() {
# 			// Execute as many scripts in order as we can
# 			var pendingScript;
# 			while (pendingScripts[0] && pendingScripts[0].readyState === 'loaded') {
# 				pendingScript = pendingScripts.shift();
# 				// avoid future loading events from this script (eg, if src changes)
# 				pendingScript.onreadystatechange = null;
# 				// can't just appendChild, old IE bug if element isn't closed
# 				firstScript.parentNode.insertBefore(pendingScript, firstScript);
# 			}
# 		}
#
# 		// loop through our script urls
# 		while (scriptObject = scriptsArray.shift()) {
# 			if ('async' in firstScript) { // modern browsers
# 				scriptTag = document.createElement('script');
#
# 				if (scriptObject.crossorigin) {
# 					scriptTag.setAttribute("crossorigin", "anonymous");
# 				}
#
# 				scriptTag.onload = function (event) {
# 					if (event.path || event.target) {
# 						var src = event.path ? event.path[0].src : event.target.src;
#
# 						win.scriptOrder.push(src);
# 					}
# 				};
#
# 				scriptTag.async = false;
# 				scriptTag.src = scriptObject.url;
# 				fragment.appendChild(scriptTag);
# 			}
# 			else if (firstScript.readyState) { // IE<10
# 				// create a script and add it to our todo pile
# 				scriptTag = document.createElement('script');
#
# 				if (scriptObject.crossorigin) {
# 					scriptTag.setAttribute("crossorigin", "anonymous");
# 				}
#
# 				pendingScripts.push(scriptTag);
# 				// listen for state changes
# 				scriptTag.onreadystatechange = stateChange;
# 				// must set src AFTER adding onreadystatechange listener
# 				// else we’ll miss the loaded event for cached scripts
# 				scriptTag.src = scriptObject.url;
# 			}
# 			else { // fall back to defer
# 				document.write('<script src="' + scriptObject.url + '" defer></' + 'script>');
# 			}
# 		}
#
# 		//modern browsers IE10 >= append script tags added to html fragment
# 		if ('async' in firstScript) {
# 			documentHead.appendChild(fragment);
# 		}
# 	})();
# })(window);
# </script>
# </main>
# </body>
# </html>

# %%
#grabs each product
containers = page_soup.findAll("div",{"class":"item-container"})

filename = "newegglaptops.csv"
f = open(filename,"w")

headers = "Make,Product_Desc,Shipping,Price\n"

f.write(headers)

for container in containers:
    make = container.div.div.a.img["title"]
    
    title_container = container.findAll("a",{"class":"item-title"})
    product_name = title_container[0].text
    
    shipping_container = container.findAll("li",{"class":"price-ship"})
    shipping = shipping_container[0].text.strip()
    
    price_container = container.findAll("li",{"class":"price-current"})
    price = price_container[0].strong.text + price_container[0].sup.text
    print('Make :' + make)
    print('Product Name :' + product_name)
    print('Shipping :' + shipping)
    print('Price :' + price)
    # print("="*100)
    f.write(make + "," + product_name.replace(",","|") + "," + shipping + "," + price + "\n")

f.close()
